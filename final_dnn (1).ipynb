# %%
# Basic packages always been used
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Data scaling
from sklearn.preprocessing import MinMaxScaler

# Function for spilting training & testing data set
from sklearn.model_selection import train_test_split

# Tensorflow sequential models
from tensorflow import keras
from keras import backend as clear
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.optimizers import SGD
from keras.optimizers import Adam
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.model_selection import TimeSeriesSplit

# Functions for evaluation
from sklearn.metrics import mean_absolute_error #MAE
from sklearn.metrics import mean_squared_error #MSE,RMSE
from sklearn.metrics import mean_absolute_percentage_error #MAPE

# %%
# Symmetric Mean Absolute Percentage Error (SMAPE)
def SMAPE_calulate(y_true, y_pred):
    n = len(y_true)
    SMAPE=(100 / n) * np.sum(2 * np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true)))
    return SMAPE

# Relative Absolute Error (RAE)
def RAE_calculate(y_true, y_pred):
    abs_errors = np.abs(y_true - y_pred)
    denominator = np.sum(np.abs(y_true - np.mean(y_true)))
    RAE=np.sum(abs_errors/denominator)
    return RAE

# Mean Relative Absolute Error (MRAE)
def MRAE_calculate(y_true, y_pred):
    n=len(y_true)
    abs_errors = np.abs(y_true - y_pred)
    denominator = np.sum(np.abs(y_true - np.mean(y_true)))
    RAE=np.sum(abs_errors/denominator)
    MRAE=RAE/n
    return MRAE

# Median Relative Absolute Error (MdRAE) comparing with benchmark
# Note: By default, the bench value is the mean of actual value
def MdRAE_calculate(y_true, y_pred, bench=None):
    if bench==None:
        bench=np.mean(y_true)
        MdRAE=np.median(np.abs(y_true - y_pred)/np.abs(y_true - bench))
        return MdRAE,bench
    else:
        MdRAE=np.median(np.abs(y_true - y_pred)/np.abs(y_true - bench))
        return MdRAE

# Relative Squared Error (RSE) & Root Relative Squared Error (RRSE)
def RSE_calculate(y_true, y_pred, Root=False):
    mse = np.mean((y_true - y_pred)**2)
    denominator = np.var(y_true)
    RSE=mse/denominator

    if Root==True:
        return np.sqrt(RSE)
    else:
        return RSE

# %%
#load data(sometimes need to use "/")
#df = pd.read_csv('D:/pythonData/python_demo_data/Rainfall_Forecast.csv')
# Colab
df = pd.read_csv('/content/drive/MyDrive/MSFT.csv')
df
# Out:
#            Date       Close
# 0      2/6/2014   40.790001
# 1      3/6/2014   40.290001
# 2      4/6/2014   40.320000
# 3      5/6/2014   41.209999
# 4      6/6/2014   41.480000
# ...         ...         ...
# 2260  23/5/2023  315.260010
# 2261  24/5/2023  313.850006
# 2262  25/5/2023  325.920013
# 2263  26/5/2023  332.890015
# 2264  30/5/2023  331.209991
#
# [2265 rows x 2 columns]

# %%
# Date is converted into special data type of pandas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2265 non-null   object
#  1   Close   2265 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 35.5+ KB

# %%
# View descriptive statistics of target variable
# Pandas will automatically ignore date if the correct data type has been converted
new_df = df
new_df.describe()
# Out:
#              Close
# count  2265.000000
# mean    142.370631
# std      91.763318
# min      40.290001
# 25%      57.419998
# 50%     108.300003
# 75%     231.600006
# max     343.109985

# %%
# Plot Y and its corresponding date
# Figure setting
plt.figure(figsize=(24,8),dpi=300)
plt.title('MSFT Stock Price Between 2022 Jun 1 and 2023 May 31',weight='bold',fontsize=24)
plt.xlabel('Date',fontsize=18,weight='bold')
plt.ylabel('Relative Humidity',fontsize=18,weight='bold')

# Actual by predicted plot
plt.plot(new_df['Date'],new_df['Close'],marker='.',color='blue')

# Set the axis
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
# Create 3 lags
new_df['Lag_1']=new_df['Close'].shift(1).copy()
new_df['Lag_2']=new_df['Close'].shift(2).copy()
new_df['Lag_3']=new_df['Close'].shift(3).copy()
new_df.head()
# Out:
#        Date      Close      Lag_1      Lag_2      Lag_3
# 0  2/6/2014  40.790001        NaN        NaN        NaN
# 1  3/6/2014  40.290001  40.790001        NaN        NaN
# 2  4/6/2014  40.320000  40.290001  40.790001        NaN
# 3  5/6/2014  41.209999  40.320000  40.290001  40.790001
# 4  6/6/2014  41.480000  41.209999  40.320000  40.290001

# %%
# Drop out missing values and rest index
clean_df=new_df.dropna(axis=0, how='any').copy()
clean_df=clean_df.reset_index(drop=True)
clean_df
# Out:
#            Date       Close       Lag_1       Lag_2       Lag_3
# 0      5/6/2014   41.209999   40.320000   40.290001   40.790001
# 1      6/6/2014   41.480000   41.209999   40.320000   40.290001
# 2      9/6/2014   41.270000   41.480000   41.209999   40.320000
# 3     10/6/2014   41.110001   41.270000   41.480000   41.209999
# 4     11/6/2014   40.860001   41.110001   41.270000   41.480000
# ...         ...         ...         ...         ...         ...
# 2257  23/5/2023  315.260010  321.179993  318.339996  318.519989
# 2258  24/5/2023  313.850006  315.260010  321.179993  318.339996
# 2259  25/5/2023  325.920013  313.850006  315.260010  321.179993
# 2260  26/5/2023  332.890015  325.920013  313.850006  315.260010
# 2261  30/5/2023  331.209991  332.890015  325.920013  313.850006
#
# [2262 rows x 5 columns]

# %%
# Train data
x=clean_df.drop(['Date','Close'],axis=1).copy()
x.head()
# Out:
#        Lag_1      Lag_2      Lag_3
# 0  40.320000  40.290001  40.790001
# 1  41.209999  40.320000  40.290001
# 2  41.480000  41.209999  40.320000
# 3  41.270000  41.480000  41.209999
# 4  41.110001  41.270000  41.480000

# %%
# Test data
y=clean_df['Close'].copy()
y.head()
# Out:
# 0    41.209999
# 1    41.480000
# 2    41.270000
# 3    41.110001
# 4    40.860001
# Name: Close, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,shuffle=False)

# %%
x_train_tuning,x_valid,y_train_tuining,y_valid = train_test_split(x_train,y_train,test_size=0.2,shuffle=False)

# %%
##1
#set x (make prediction)
# Train
#x_train=Rol_training_1.drop(['Date','Close'],axis=1).copy()
#minimax scaling
MMscaler=MinMaxScaler(feature_range=(0, 1))
scalingT=MMscaler.fit_transform(x_train_tuning)
scaled_x_train=pd.DataFrame(data=scalingT)
scaled_x_train
# Out:
#              0         1         2
# 0     0.000202  0.000000  0.003369
# 1     0.006199  0.000202  0.000000
# 2     0.008018  0.006199  0.000202
# 3     0.006603  0.008018  0.006199
# 4     0.005525  0.006603  0.008018
# ...        ...       ...       ...
# 1442  0.875143  0.860993  0.879995
# 1443  0.794353  0.875143  0.860993
# 1444  0.820160  0.794353  0.875143
# 1445  0.892797  0.820160  0.794353
# 1446  0.837006  0.892797  0.820160
#
# [1447 rows x 3 columns]

# %%
from keras.losses import mse
from keras.backend import sqrt

def my_RMSE(y_true, y_pred):
    return sqrt(mse(y_true, y_pred))

# Register custom object
#from keras.utils.generic_utils import get_custom_objects for pc
from tensorflow.keras.saving import get_custom_objects
get_custom_objects().update({'my_RMSE': my_RMSE})
#get_custom_objects().update({'my_MAPE': MRAE_calculate})

# %%
def create_model(learning_rate=0.01):
  # 6.1 Create the model
  clear.clear_session()
  model=Sequential()

  # 6.2 Add input layer & first hidden layer
  model.add(Dense(units=6, input_dim=3, activation='relu'))

  # 6.3 Add second hidden layer
  model.add(Dense(units=12, activation='linear'))

  #model.add(Dropout(rate=0.2))

  # 6.4 Add third hidden layer
  model.add(Dense(units=24, activation='linear'))

  model.add(Dense(units=48, activation='relu'))

  #model.add(Dropout(rate=0.4))

  model.add(Dense(units=96, activation='relu'))

  # 6.5 Add output layer
  model.add(Dense(units=1, activation='linear'))

  # 6.6 Compile the defined Net
  #opt=SGD(learning_rate=0.001,momentum=0.5)
  opt=Adam(learning_rate=learning_rate,beta_1=0.95)
  model.compile(loss='MSE',optimizer=opt, metrics=['mean_absolute_percentage_error'])

  # Finally check the model
  return model

model = KerasRegressor(build_fn=create_model, epochs=100,verbose=0)
cv_inner = TimeSeriesSplit(n_splits=3)
learning_rate = [0.01,0.001,0.0001]
batch_size = [32,64]
param_grid = dict(batch_size=batch_size,learning_rate=learning_rate)
grid = GridSearchCV(estimator=model,param_grid=param_grid,cv=cv_inner,scoring='neg_root_mean_squared_error',n_jobs=-1)
grid_result = grid.fit(scaled_x_train,y_train_tuining)

print("Best:%fusing%s"%(grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# <ipython-input-16-eb21cc8f3b59>:34: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=create_model, epochs=100,verbose=0)
# Best:-1.544474using{'batch_size': 64, 'learning_rate': 0.01}
# -1.825388 (1.193680) with: {'batch_size': 32, 'learning_rate': 0.01}
# -1.680420 (0.904792) with: {'batch_size': 32, 'learning_rate': 0.001}
# -3.195034 (0.928931) with: {'batch_size': 32, 'learning_rate': 0.0001}
# -1.544474 (0.600943) with: {'batch_size': 64, 'learning_rate': 0.01}
# -3.181864 (0.731916) with: {'batch_size': 64, 'learning_rate': 0.001}
# -9.270825 (6.467099) with: {'batch_size': 64, 'learning_rate': 0.0001}

# %%
# Train data
Forecast_train_data=clean_df.iloc[0:1812,:].copy()
Forecast_train_data
# Out:
#            Date       Close       Lag_1       Lag_2       Lag_3
# 0      5/6/2014   41.209999   40.320000   40.290001   40.790001
# 1      6/6/2014   41.480000   41.209999   40.320000   40.290001
# 2      9/6/2014   41.270000   41.480000   41.209999   40.320000
# 3     10/6/2014   41.110001   41.270000   41.480000   41.209999
# 4     11/6/2014   40.860001   41.110001   41.270000   41.480000
# ...         ...         ...         ...         ...         ...
# 1807   9/8/2021  288.329987  289.459991  289.519989  286.510010
# 1808  10/8/2021  286.440002  288.329987  289.459991  289.519989
# 1809  11/8/2021  286.950012  286.440002  288.329987  289.459991
# 1810  12/8/2021  289.809998  286.950012  286.440002  288.329987
# 1811  13/8/2021  292.850006  289.809998  286.950012  286.440002
#
# [1812 rows x 5 columns]

# %%
# Test data
Forecast_test_data=clean_df.iloc[1812:2265,:].copy()
Forecast_test_data
# Out:
#            Date       Close       Lag_1       Lag_2       Lag_3
# 1812  16/8/2021  294.600006  292.850006  289.809998  286.950012
# 1813  17/8/2021  293.079987  294.600006  292.850006  289.809998
# 1814  18/8/2021  290.730011  293.079987  294.600006  292.850006
# 1815  19/8/2021  296.769989  290.730011  293.079987  294.600006
# 1816  20/8/2021  304.359985  296.769989  290.730011  293.079987
# ...         ...         ...         ...         ...         ...
# 2257  23/5/2023  315.260010  321.179993  318.339996  318.519989
# 2258  24/5/2023  313.850006  315.260010  321.179993  318.339996
# 2259  25/5/2023  325.920013  313.850006  315.260010  321.179993
# 2260  26/5/2023  332.890015  325.920013  313.850006  315.260010
# 2261  30/5/2023  331.209991  332.890015  325.920013  313.850006
#
# [450 rows x 5 columns]

# %%
# X all train data
x_forecast_train=Forecast_train_data.drop(['Date','Close'],axis=1).copy()
# Y all train data
y_forecast_train=Forecast_train_data['Close'].copy()

# %%
# Create the model
clear.clear_session()
Fmodel=Sequential()

# 6.2 Add input layer & first hidden layer
Fmodel.add(Dense(units=6, input_dim=3, activation='relu'))

# 6.3 Add second hidden layer
Fmodel.add(Dense(units=12, activation='linear'))

#Fmodel.add(Dropout(rate=0.2))

# 6.4 Add third hidden layer
Fmodel.add(Dense(units=24, activation='linear'))

Fmodel.add(Dense(units=48, activation='relu'))

#Fmodel.add(Dropout(rate=0.4))

Fmodel.add(Dense(units=96, activation='relu'))

# 6.5 Add output layer
Fmodel.add(Dense(units=1, activation='linear'))

# Compile the defined Net
#opt=SGD(learning_rate=0.001,momentum=0.5)
opt=Adam(learning_rate=0.01,beta_1=0.95)
Fmodel.compile(loss='MSE', optimizer=opt, metrics=['mean_absolute_percentage_error'])

# Finally check the model
Fmodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 24
#
#  dense_1 (Dense)             (None, 12)                84
#
#  dense_2 (Dense)             (None, 24)                312
#
#  dense_3 (Dense)             (None, 48)                1200
#
#  dense_4 (Dense)             (None, 96)                4704
#
#  dense_5 (Dense)             (None, 1)                 97
#
# =================================================================
# Total params: 6,421
# Trainable params: 6,421
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Store in the history for more useful information
history=Fmodel.fit(x_forecast_train, y_forecast_train, epochs=100, batch_size=32,verbose=1)
# Out:
# Epoch 1/100
# 57/57 [==============================] - 0s 1ms/step - loss: 923.7927 - mean_absolute_percentage_error: 14.4293
# Epoch 2/100
# 57/57 [==============================] - 0s 1ms/step - loss: 16.7419 - mean_absolute_percentage_error: 2.5366
# Epoch 3/100
# 57/57 [==============================] - 0s 1ms/step - loss: 7.7800 - mean_absolute_percentage_error: 1.6422
# Epoch 4/100
# 57/57 [==============================] - 0s 1ms/step - loss: 7.1138 - mean_absolute_percentage_error: 1.5260
# Epoch 5/100
# 57/57 [==============================] - 0s 1ms/step - loss: 6.3846 - mean_absolute_percentage_error: 1.3836
# Epoch 6/100
# 57/57 [==============================] - 0s 1ms/step - loss: 5.9037 - mean_absolute_percentage_error: 1.3287
# Epoch 7/100
# 57/57 [==============================] - 0s 1ms/step - loss: 6.0145 - mean_absolute_percentage_error: 1.3132
# Epoch 8/100
# 57/57 [==============================] - 0s 1ms/step - loss: 7.8665 - mean_absolute_percentage_error: 1.5916
# Epoch 9/100
# 57/57 [==============================] - 0s 1ms/step - loss: 7.5730 - mean_absolute_percentage_error: 1.5457
# Epoch 10/100
# 57/57 [==============================] - 0s 1ms/step - loss: 7.6804 - mean_absolute_percentage_error: 1.6599
# Epoch 11/100
# 57/57 [==============================] - 0s 1ms/step - loss: 8.7171 - mean_absolute_percentage_error: 1.7568
# Epoch 12/100
# 57/57 [==============================] - 0s 1ms/step - loss: 9.3866 - mean_absolute_percentage_error: 1.8641
# Epoch 13/100
# 57/57 [==============================] - 0s 1ms/step - loss: 8.0739 - mean_absolute_percentage_error: 1.6250
# Epoch 14/100
# 57/57 [==============================] - 0s 1ms/step - loss: 6.6577 - mean_absolute_percentage_error: 1.4310
# Epoch 15/100
# 57/57 [==============================] - 0s 1ms/step - loss: 8.0424 - mean_absolute_percentage_error: 1.6181
# Epoch 16/100
# 57/57 [==============================] - 0s 1ms/step - loss: 6.2515 - mean_absolute_percentage_error: 1.3851
# Epoch 17/100
# 57/57 [==============================] - 0s 1ms/step - loss: 12.4842 - mean_absolute_percentage_error: 2.2000
# Epoch 18/100
# 57/57 [==============================] - 0s 1ms/step - loss: 7.2471 - mean_absolute_percentage_error: 1.5331
# Epoch 19/100
# 57/57 [==============================] - 0s 1ms/step - loss: 9.6322 - mean_absolute_percentage_error: 1.8565
# Epoch 20/100
# 57/57 [==============================] - 0s 1ms/step - loss: 6.8068 - mean_absolute_percentage_error: 1.4569
# Epoch 21/100
# 57/57 [==============================] - 0s 1ms/step - loss: 6.9821 - mean_absolute_percentage_error: 1.4609
# Epoch 22/100
# 57/57 [==============================] - 0s 1ms/step - loss: 9.8679 - mean_absolute_percentage_error: 1.9233
# Epoch 23/100
# 57/57 [==============================] - 0s 1ms/step - loss: 6.4397 - mean_absolute_percentage_error: 1.4335
# Epoch 24/100
# 57/57 [==============================] - 0s 1ms/step - loss: 7.6388 - mean_absolute_percentage_error: 1.5448
# Epoch 25/100
# 57/57 [==============================] - 0s 1ms/step - loss: 31.2443 - mean_absolute_percentage_error: 3.7731
# Epoch 26/100
# 57/57 [==============================] - 0s 1ms/step - loss: 69.5608 - mean_absolute_percentage_error: 5.7656
# Epoch 27/100
# 57/57 [==============================] - 0s 1ms/step - loss: 21.2955 - mean_absolute_percentage_error: 2.9923
# Epoch 28/100
# 57/57 [==============================] - 0s 1ms/step - loss: 7.6728 - mean_absolute_percentage_error: 1.5656
# Epoch 29/100
# 57/57 [==============================] - 0s 1ms/step - loss: 6.8730 - mean_absolute_percentage_error: 1.4329
# Epoch 30/100
# 57/57 [==============================] - 0s 1ms/step - loss: 6.2100 - mean_absolute_percentage_error: 1.3794
# Epoch 31/100
# 57/57 [==============================] - 0s 1ms/step - loss: 9.6600 - mean_absolute_percentage_error: 1.8759
# Epoch 32/100
# 57/57 [==============================] - 0s 1ms/step - loss: 9.9391 - mean_absolute_percentage_error: 1.9127
# Epoch 33/100
# 57/57 [==============================] - 0s 1ms/step - loss: 9.5597 - mean_absolute_percentage_error: 1.8540
# Epoch 34/100
# 57/57 [==============================] - 0s 1ms/step - loss: 9.7024 - mean_absolute_percentage_error: 1.8408
# Epoch 35/100
# 57/57 [==============================] - 0s 1ms/step - loss: 6.7225 - mean_absolute_percentage_error: 1.4243
# Epoch 36/100
# 57/57 [==============================] - 0s 1ms/step - loss: 10.5299 - mean_absolute_percentage_error: 1.9613
# Epoch 37/100
# 57/57 [==============================] - 0s 1ms/step - loss: 7.3286 - mean_absolute_percentage_error: 1.5422
# Epoch 38/100
# 57/57 [==============================] - 0s 1ms/step - loss: 5.3187 - mean_absolute_percentage_error: 1.2340
# Epoch 39/100
# 57/57 [==============================] - 0s 1ms/step - loss: 9.7352 - mean_absolute_percentage_error: 1.9533
# Epoch 40/100
# 57/57 [==============================] - 0s 1ms/step - loss: 11.7476 - mean_absolute_percentage_error: 2.0514
# Epoch 41/100
# 57/57 [==============================] - 0s 1ms/step - loss: 12.4326 - mean_absolute_percentage_error: 2.1873
# Epoch 42/100
# 57/57 [==============================] - 0s 1ms/step - loss: 14.5459 - mean_absolute_percentage_error: 2.3072
# Epoch 43/100
# 57/57 [==============================] - 0s 1ms/step - loss: 10.0791 - mean_absolute_percentage_error: 1.8944
# Epoch 44/100
# 57/57 [==============================] - 0s 1ms/step - loss: 9.4093 - mean_absolute_percentage_error: 1.8390
# Epoch 45/100
# 57/57 [==============================] - 0s 1ms/step - loss: 11.8974 - mean_absolute_percentage_error: 2.1231
# Epoch 46/100
# 57/57 [==============================] - 0s 1ms/step - loss: 6.5560 - mean_absolute_percentage_error: 1.4245
# Epoch 47/100
# 57/57 [==============================] - 0s 1ms/step - loss: 6.6388 - mean_absolute_percentage_error: 1.4659
# Epoch 48/100
# 57/57 [==============================] - 0s 2ms/step - loss: 6.2971 - mean_absolute_percentage_error: 1.4044
# Epoch 49/100
# 57/57 [==============================] - 0s 1ms/step - loss: 6.0265 - mean_absolute_percentage_error: 1.3629
# Epoch 50/100
# 57/57 [==============================] - 0s 1ms/step - loss: 7.8519 - mean_absolute_percentage_error: 1.6548
# Epoch 51/100
# 57/57 [==============================] - 0s 1ms/step - loss: 8.5758 - mean_absolute_percentage_error: 1.7475
# Epoch 52/100
# 57/57 [==============================] - 0s 1ms/step - loss: 10.9327 - mean_absolute_percentage_error: 1.9401
# Epoch 53/100
# 57/57 [==============================] - 0s 2ms/step - loss: 16.0223 - mean_absolute_percentage_error: 2.5095
# Epoch 54/100
# 57/57 [==============================] - 0s 2ms/step - loss: 10.2359 - mean_absolute_percentage_error: 1.9860
# Epoch 55/100
# 57/57 [==============================] - 0s 2ms/step - loss: 12.7501 - mean_absolute_percentage_error: 2.1516
# Epoch 56/100
# 57/57 [==============================] - 0s 2ms/step - loss: 7.1734 - mean_absolute_percentage_error: 1.4980
# Epoch 57/100
# 57/57 [==============================] - 0s 2ms/step - loss: 7.0258 - mean_absolute_percentage_error: 1.5011
# Epoch 58/100
# 57/57 [==============================] - 0s 2ms/step - loss: 7.9053 - mean_absolute_percentage_error: 1.6277
# Epoch 59/100
# 57/57 [==============================] - 0s 2ms/step - loss: 9.2126 - mean_absolute_percentage_error: 1.8039
# Epoch 60/100
# 57/57 [==============================] - 0s 2ms/step - loss: 8.2163 - mean_absolute_percentage_error: 1.6820
# Epoch 61/100
# 57/57 [==============================] - 0s 2ms/step - loss: 13.8252 - mean_absolute_percentage_error: 2.3516
# Epoch 62/100
# 57/57 [==============================] - 0s 2ms/step - loss: 26.1081 - mean_absolute_percentage_error: 3.4491
# Epoch 63/100
# 57/57 [==============================] - 0s 2ms/step - loss: 33.3627 - mean_absolute_percentage_error: 3.8877
# Epoch 64/100
# 57/57 [==============================] - 0s 2ms/step - loss: 17.5518 - mean_absolute_percentage_error: 2.6431
# Epoch 65/100
# 57/57 [==============================] - 0s 2ms/step - loss: 11.1100 - mean_absolute_percentage_error: 1.9932
# Epoch 66/100
# 57/57 [==============================] - 0s 2ms/step - loss: 11.6497 - mean_absolute_percentage_error: 2.0471
# Epoch 67/100
# 57/57 [==============================] - 0s 2ms/step - loss: 9.9732 - mean_absolute_percentage_error: 1.8631
# Epoch 68/100
# 57/57 [==============================] - 0s 2ms/step - loss: 6.9598 - mean_absolute_percentage_error: 1.4910
# Epoch 69/100
# 57/57 [==============================] - 0s 2ms/step - loss: 6.0980 - mean_absolute_percentage_error: 1.3819
# Epoch 70/100
# 57/57 [==============================] - 0s 2ms/step - loss: 7.8113 - mean_absolute_percentage_error: 1.6106
# Epoch 71/100
# 57/57 [==============================] - 0s 2ms/step - loss: 10.0464 - mean_absolute_percentage_error: 1.9174
# Epoch 72/100
# 57/57 [==============================] - 0s 2ms/step - loss: 11.5158 - mean_absolute_percentage_error: 2.0922
# Epoch 73/100
# 57/57 [==============================] - 0s 2ms/step - loss: 9.6708 - mean_absolute_percentage_error: 1.8582
# Epoch 74/100
# 57/57 [==============================] - 0s 2ms/step - loss: 26.0185 - mean_absolute_percentage_error: 3.3530
# Epoch 75/100
# 57/57 [==============================] - 0s 2ms/step - loss: 7.8986 - mean_absolute_percentage_error: 1.6030
# Epoch 76/100
# 57/57 [==============================] - 0s 2ms/step - loss: 5.6344 - mean_absolute_percentage_error: 1.2992
# Epoch 77/100
# 57/57 [==============================] - 0s 2ms/step - loss: 9.5502 - mean_absolute_percentage_error: 1.7942
# Epoch 78/100
# 57/57 [==============================] - 0s 2ms/step - loss: 7.8531 - mean_absolute_percentage_error: 1.5937
# Epoch 79/100
# 57/57 [==============================] - 0s 2ms/step - loss: 7.4797 - mean_absolute_percentage_error: 1.5649
# Epoch 80/100
# 57/57 [==============================] - 0s 2ms/step - loss: 7.3559 - mean_absolute_percentage_error: 1.5454
# Epoch 81/100
# 57/57 [==============================] - 0s 2ms/step - loss: 10.4881 - mean_absolute_percentage_error: 1.8917
# Epoch 82/100
# 57/57 [==============================] - 0s 2ms/step - loss: 11.1791 - mean_absolute_percentage_error: 2.1103
# Epoch 83/100
# 57/57 [==============================] - 0s 1ms/step - loss: 33.2144 - mean_absolute_percentage_error: 3.8007
# Epoch 84/100
# 57/57 [==============================] - 0s 1ms/step - loss: 10.5154 - mean_absolute_percentage_error: 1.9861
# Epoch 85/100
# 57/57 [==============================] - 0s 1ms/step - loss: 8.3112 - mean_absolute_percentage_error: 1.7434
# Epoch 86/100
# 57/57 [==============================] - 0s 1ms/step - loss: 11.0629 - mean_absolute_percentage_error: 2.0209
# Epoch 87/100
# 57/57 [==============================] - 0s 1ms/step - loss: 14.2524 - mean_absolute_percentage_error: 2.3717
# Epoch 88/100
# 57/57 [==============================] - 0s 1ms/step - loss: 9.0109 - mean_absolute_percentage_error: 1.7268
# Epoch 89/100
# 57/57 [==============================] - 0s 1ms/step - loss: 8.0497 - mean_absolute_percentage_error: 1.6754
# Epoch 90/100
# 57/57 [==============================] - 0s 1ms/step - loss: 8.2564 - mean_absolute_percentage_error: 1.6534
# Epoch 91/100
# 57/57 [==============================] - 0s 1ms/step - loss: 13.3910 - mean_absolute_percentage_error: 2.3155
# Epoch 92/100
# 57/57 [==============================] - 0s 1ms/step - loss: 7.8580 - mean_absolute_percentage_error: 1.5853
# Epoch 93/100
# 57/57 [==============================] - 0s 1ms/step - loss: 8.5144 - mean_absolute_percentage_error: 1.7497
# Epoch 94/100
# 57/57 [==============================] - 0s 1ms/step - loss: 8.8242 - mean_absolute_percentage_error: 1.7520
# Epoch 95/100
# 57/57 [==============================] - 0s 1ms/step - loss: 8.1581 - mean_absolute_percentage_error: 1.5819
# Epoch 96/100
# 57/57 [==============================] - 0s 1ms/step - loss: 8.1709 - mean_absolute_percentage_error: 1.6316
# Epoch 97/100
# 57/57 [==============================] - 0s 1ms/step - loss: 6.9800 - mean_absolute_percentage_error: 1.5142
# Epoch 98/100
# 57/57 [==============================] - 0s 1ms/step - loss: 5.6118 - mean_absolute_percentage_error: 1.2842
# Epoch 99/100
# 57/57 [==============================] - 0s 1ms/step - loss: 6.6154 - mean_absolute_percentage_error: 1.3903
# Epoch 100/100
# 57/57 [==============================] - 0s 1ms/step - loss: 10.6675 - mean_absolute_percentage_error: 1.9831

# %%
# 7.3 Save the trained model
#Fmodel.save('D:/data_analysis/PyExport/Rainfall_forecast_ANN_trained_model.h5')
# Colab
Fmodel.save('House_Rent_ANN_trained_model.h5')
print('Model has been saved...')
# Out:
# Model has been saved...

# %%
# 7.4 Restore the saved model for testing
#ANN_model=keras.models.load_model('D:/data_analysis/PyExport/Rainfall_forecast_ANN_trained_model.h5')
# Colab
ANN_model=keras.models.load_model('/content/House_Rent_ANN_trained_model.h5')
print('Model successfully loaded...')
# Out:
# Model successfully loaded...

# %%
# X test
x_forecast_test=Forecast_test_data.drop(['Date','Close'],axis=1).copy()
# Y test
y_forecast_test=Forecast_test_data['Close'].copy()

# %%
# 8.1 Make prediction
prediction=np.round((ANN_model.predict_on_batch(x_forecast_test)),2)
pred_values=[]
for i in range(0,len(prediction)):
    value=prediction[i][0]
    pred_values.append(value)

# %%
Results=pd.DataFrame({'Date':Forecast_test_data['Date'],'Y_true':Forecast_test_data['Close'],'Predict':pred_values})
Results['abs Error']=np.abs(Results['Y_true']-Results['Predict'])
Results
# Out:
#            Date      Y_true     Predict  abs Error
# 1812  16/8/2021  294.600006  300.170013   5.570007
# 1813  17/8/2021  293.079987  302.279999   9.200012
# 1814  18/8/2021  290.730011  301.899994  11.169983
# 1815  19/8/2021  296.769989  300.489990   3.720001
# 1816  20/8/2021  304.359985  304.649994   0.290009
# ...         ...         ...         ...        ...
# 2257  23/5/2023  315.260010  330.130005  14.869995
# 2258  24/5/2023  313.850006  325.660004  11.809998
# 2259  25/5/2023  325.920013  325.100006   0.820007
# 2260  26/5/2023  332.890015  332.820007   0.070008
# 2261  30/5/2023  331.209991  338.130005   6.920014
#
# [450 rows x 4 columns]

# %%
# 8.2 Calculating the mertics
MAE=mean_absolute_error(y_forecast_test,pred_values)
MSE=mean_squared_error(y_forecast_test,pred_values,squared=True)
RMSE=mean_squared_error(y_forecast_test,pred_values,squared=False)
MAPE=mean_absolute_percentage_error(y_forecast_test,pred_values)
SMAPE=SMAPE_calulate(y_forecast_test,pred_values)
RAE=RAE_calculate(y_forecast_test,pred_values)
MRAE=MRAE_calculate(y_forecast_test,pred_values)
MdRAE=MdRAE_calculate(y_forecast_test,pred_values)
RSE=RSE_calculate(y_forecast_test,pred_values,Root=False)
RRSE=RSE_calculate(y_forecast_test,pred_values,Root=True)

print('MAE:',round(MAE,3))
print('MSE:',round(MSE,3))
print('RMSE:',round(RMSE,3))
print('MAPE:',round(MAPE*100,3),'%')
print('SMAPE:',round(SMAPE,3),'%')
print('RAE:',round(RAE,3))
print('MRAE:',MRAE)
print('MdRAE:',round(MdRAE[0],3),'bench:',round(MdRAE[1],3))
print('RSE:',round(RSE,3))
print('RRSE:',round(RRSE,3))
# Out:
# MAE: 8.681
# MSE: 102.08
# RMSE: 10.103
# MAPE: 3.14 %
# SMAPE: 3.075 %
# RAE: 0.329
# MRAE: 0.0007313925501445488
# MdRAE: 0.316 bench: 279.922
# RSE: 0.106
# RRSE: 0.326

# %%
# Plot Y and its corresponding date
# Figure setting
plt.figure(figsize=(24,8),dpi=300)
plt.title('Monthly Relative Humidity Forecast Comparison (2018-2020)',weight='bold',fontsize=24)
plt.xlabel('Date',fontsize=18,weight='bold')
plt.ylabel('Relative Humidity',fontsize=18,weight='bold')

# Comparison of actual value and predicted value according to Date
plt.plot(clean_df.iloc[1800:,0],clean_df.iloc[1800:,1],marker='o',color='blue',label='Actual')
plt.plot(Results['Date'],Results['Predict'],marker='o',color='red',label='Forecast')

# Set the axis
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

# Set legends
plt.legend(loc=4,fontsize=20)

plt.show()

# %%
# Lock the scale of axis by Y_true
max_value=500+5
min_value=0-5

# Figure setting
plt.figure(figsize=(10,10),dpi=300)
plt.title('Actual by predicted plot',weight='bold',fontsize=24)
plt.xlabel('Actual (Y-true)',fontsize=18,weight='bold')
plt.ylabel('Forecast',fontsize=18,weight='bold')

# Perfect model reference line
plt.plot([min_value,max_value], [min_value,max_value], linestyle='--',color='red')

# Actual by predicted plot
plt.scatter(Results.iloc[:,1],Results.iloc[:,2],marker='.',color='blue')

# Set the axis
plt.ylim(0-5,max_value)
plt.xlim(0-5,max_value)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
